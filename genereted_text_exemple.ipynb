# %% [markdown]
# <a id="libraries"></a>
# # <b><span style='color:#ff6200'> Generated text exemple</span></b>

# %% [markdown]
# Here are some examples of text generated by the different models I have trained. $\newline$
# To test the models, you can use an excerpt from Shakespeare's text in `input.txt`  as input and provide it as a prompt.

# %% [markdown]
# <h2 align="left"><font color=#ff6200>Bigram Model:</font></h2>
#
# **Step**: 2999 $\newline$
# **Train loss**: 2.4871 $\newline$
# **Loss Value**: 2.5094
#
# **Prompt**: To be or not to be $\newline$
# **Generated**: To be or not to bere r pivedoves str willld spra ve bend; thillanknke ffo $\newline$
# geristiowout WE:$\newline$
# Thityot cit cotomad you ch $\newline$
#
# **Prompt**: Such a nature,$\newline$
# **Generated**: Such a nature, conved? $\newline$
# Lhawoougwhat f t t kind, o wiss, ns, E d? $\newline$
# INENGurerthe lade $\newline$
# Bgs's, mar bif ariser bll t wis $\newline$

# %% [markdown]
# <h2 align="left"><font color=#ff6200>Single head attention model</font></h2>

# %% [markdown]
# #### Training with a CPU
# **Step**: 2999 $\newline$
# **Train loss**: 2.1060 $\newline$
# **Loss Value**: 2.1737
#
# **Prompt**: to be or not to be $\newline$
# **Generated**: to be or not to beadswaith l warcis.
#
# I'd sint cou arusef nosaven en moou? $\newline$
# Love w will. $\newline$
# UFOKENTIUCSER: $\newline$
# The bliy lid Bold lous arin as; and seargnd ds: fnocke,y soure no
#
# **Prompt**: Such a nature $\newline$
# **Generated**: Such a naturest sherreas mnstes powrseapr, mowron, $\newline$
# Ae, haiet's f well doutria cond ofelperite asto gay anjer thois allice to mare faibemfe sky th thath fie ofit ca
#
# **Prompt**: Such a nature,Tickled with good success, disdains the shadowWhich he treads $\newline$
# **Generated**: $\newline$
# Such a nature,Tickled with good success, disdains the shadowWhich he treads; $\newline$
# Waiteela bet, teak's $\newline$
# Fro thounmyt eve, ing fques to, she here of howme hime hy ang ws I to was is rom; $\newline$
# Mifuetwven $\newline$
# likesf nurleche veard ead the sors $\newline$
# AUS: $\newline$
# Ondak'd uros, end, $\newline$
# That lato nemard. $\newline$
#
# Roond: $\newline$
# Haueren Egiove'sis tus far oret sign Se rve no the iloupye $\newline$
# ant weer $\newline$
#
# **Prompt**: Fame, at the which he aims, $\newline$
# **Generated**: Fame, at the which he aims, $\newline$
# Perd. $\newline$
# Cim ellag calsseweis man this and monst: anmy. $\newline$
# Andid. $\newline$
#  me. $\newline$
# Yeal's Cxelalwhe thrneptich farth kearut't stear vus, $\newline$
# Anijousn heam tone thhey deir $\newline$

# %% [markdown]
# <h2 align="left"><font color=#ff6200>Single block transforer model</font></h2>

# %% [markdown]
# #### Training with a CPU
# **Step**: 2999 $\newline$
# **Train loss**: 1.9141, $\newline$
# **Loss Value**: 1.9870

# %% [markdown]
# **Prompt**: to be or not to be $\newline$
# **Generated**: to be or not to bee.$\newline$
# Noy and peayseracamarre $\newline$
# SFor Eff attent not'dis of foll; Shat me thum, $\newline$
# That Peaday my nopa matten thalth im. $\newline$
# My are to theieS $\newline$
# CENTIO: $\newline$
# you bry, mortel'd abut, from here hup youngy to wher! $\newline$
# In, mast  $\newline$
#
# **Prompt**: Such a nature $\newline$
# **Generated**: Such a nature by of yout tablome, $\newline$
# I man sthe play be got of hurter. $\newline$
#
# BRYARNIO: $\newline$
# Nay lowild hare seou h is tore. Wrich! $\newline$
# Sirn them sand for have ie haven is damelfolloursensues tool'd, $\newline$
# Tike gore wn well deat,
# Tith'd
#
# **Prompt**: Such a nature,Tickled with good success, disdains the shadowWhich he treads $\newline$
# **Generated**: Such a nature,Tickled with good success, disdains the shadowWhich he treads $\newline$
# Lordeh man o. $\newline$
#
# COMy carilTor bind my pary uf peas with lov sir, me brepprovershey? $\newline$
# bugn stue deige spent thinke wall quesevoses,-fapeter a vir to bro hyouu maill and your land, pres, thy keaveay win $\newline$

# %% [markdown]
# <h2 align="left"><font color=#ff6200>Decoder Transformer</font></h2>

# %% [markdown]
# #### Training with a CPU
#
# batch_size = 16 $\newline$
# block_size = 64  $\newline$
# max_iters = 3000    $\newline$
# learning_rate = 3e-4 $\newline$
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# eval_interval = 300  $\newline$
# eval_iters = 100 $\newline$
# n_embd = 128     $\newline$
# n_head = 4 $\newline$
# n_layer = 3  $\newline$
# dropout = 0.2 $\newline$
#
# **Step**: 2999 $\newline$
# **Train loss**: 1.8961, $\newline$
# **Loss Value**: 1.9741

# %% [markdown]
# **Prompt**: To be or not to be $\newline$
# **Generated**: To be or not to be pownins $\newline$
# Forst deakes corighed, eard's! $\newline$
# A Rpoieir out beasild.
#
# NOM: $\newline$
# Who gave sued the noan frow's t $\newline$
#
# **Prompt**: Such a nature,Tickled with good success, disdains the shadow Which he treads $\newline$
# **Generated**: Such a nature,Tickled with good success, disdains the shadow Which he treads! $\newline$
# Shn! be thate,$\newline$
# FoF ing is tha suest ous, and thithe goed,$\newline$
# But You bed me thy loibling thrate of th

# %% [markdown]
# #### Training with a GPU-TP4 on Google Collab
#
# batch_size = 64   $\newline$
# block_size = 128   $\newline$
# max_iters = 4000       $\newline$
# learning_rate = 3e-4   $\newline$
# device = 'cuda' if torch.cuda.is_available() else 'cpu' $\newline$
# eval_interval = 500    $\newline$
# eval_iters = 200 $\newline$
# n_embd = 192 $\newline$
# n_head = 8 $\newline$
# n_layer = 6       $\newline$
# dropout = 0.1 $\newline$
#
# **Step**: 3999 $\newline$
# **Train loss**: 1.3691, $\newline$
# **Loss Value**: 1.5849

# %% [markdown]
# **Prompt**: to be or not to be $\newline$
# **Generated**: to be or not to be her is equise and smother'd $\newline$
# Is remeculg an night in the yonu. $\newline$
#
# LUCIO: $\newline$
# We do not love? $\newline$
#
# First Citize $\newline$
#
# **Prompt**: Such a nature,Tickled with good success, disdains the shadow Which he treads $\newline$
# **Generated**: Such a nature,Tickled with good success, disdains the shadow Which he treads. $\newline$
#
# GLOAUREST: $\newline$
# Thus wordds ape thy broke man by grace, $\newline$
# Sacr'd so, my lord lord. $\newline$
#
# TRESS OVERDONEY: $\newline$
# How? $\newline$

# %% [markdown]
# #### Training with a GPU-TP4 on Google Collab with greater parameters
# batch_size = 64   $\newline$
# block_size = 128   $\newline$
# max_iters = 4000       $\newline$
# learning_rate = 3e-4   $\newline$
# device = 'cuda' if torch.cuda.is_available() else 'cpu' $\newline$
# eval_interval = 500    $\newline$
# eval_iters = 200 $\newline$
# n_embd = 192 $\newline$
# n_head = 8 $\newline$
# n_layer = 6       $\newline$
# dropout = 0.1 $\newline$
#
# **Step**: 3999 $\newline$
# **Train loss**: 1.3691, $\newline$
# **Loss Value**: 1.5849

# %% [markdown]
# **Prompt**: to be or not to be $\newline$
# **Generated**: to be or not to be do $\newline$
# Thursed Catus? $\newline$
#
# First Senator: $\newline$
# Afted he past to't. $\newline$
#
# Clown: $\newline$
# I am as too long, hearted you of me; $\newline$
#
# **Prompt**: Such a nature,Tickled with good success, disdains the shadow Which he treads $\newline$
# **Generated**: Such a nature,Tickled with good success, disdains the shadow Which he treads, $\newline$
# The solving the lawful upon the unturning sensors  $\newline$
# 'Behind watch'd in Death and beggars'? No, for b $\newline$
